# %%
import glob
import pybrain
import numpy as np
from pybrain.structure import FeedForwardNetwork
from pybrain.structure import LinearLayer, SigmoidLayer
from pybrain.structure import FullConnection
from pybrain.datasets import SupervisedDataSet
from pybrain.supervised.trainers import BackpropTrainer
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline
import random
import ast
import time
import sqlalchemy
from sqlalchemy import *
from sqlalchemy import event
import sqlite3
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import *
import urllib2
import urllib
import json
import glob
import pprint
import dateutil.parser
import pprint
import re
from sklearn import linear_model, datasets
import time
from sklearn.naive_bayes import GaussianNB
import nltk
from collections import defaultdict
from sklearn import svm
pp = pprint.PrettyPrinter(indent=4)
import gevent.monkey
gevent.monkey.patch_socket()
import numpy
import time
import sqlalchemy
from sqlalchemy import *
from sqlalchemy import event
from sqlalchemy.dialects.mysql import LONGTEXT
import sqlite3
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import *
import urllib2
import urllib
import json
import pprint
import dateutil.parser
import gevent
import datetime
import marshal
from pylearn2.datasets.dense_design_matrix import DenseDesignMatrix

from __future__ import division
import os

import pylearn2
import numpy as np
from pylearn2.train import Train
from pylearn2.datasets.mnist import MNIST
from pylearn2.models import softmax_regression, mlp, svm
from pylearn2.training_algorithms import bgd, sgd
from pylearn2.termination_criteria import MonitorBased, EpochCounter
from pylearn2.train_extensions import best_params, live_monitoring
from pylearn2.utils import serial
from pylearn2.costs.mlp.dropout import Dropout
from pylearn2.costs.mlp import WeightDecay
from theano import function
from theano import tensor as T
import cPickle as pickle
# Out:
# Using gpu device 0: GRID K520

# %%
trainfile = open('usd_eur_trainingdata.csv', 'r')
testfile = open('usd_eur_testingdata.csv', 'r')

X_train = []
Y_train = []

X_test = []
Y_test = []

for line in trainfile:
    line = line.strip().split(',')
    features = line[:-3]
    outputs = line[-3:]
    X_train.append(features)
    Y_train.append([outputs[0]])

for line in testfile:
    line = line.strip().split(',')
    features = line[:-3]
    outputs = line[-3:]
    X_test.append(features)
    Y_test.append([outputs[0]])

X_train = np.asarray(X_train).astype(np.float32)
Y_train = np.asarray(Y_train).astype(np.float32)

X_test = np.asarray(X_test).astype(np.float32)
Y_test = np.asarray(Y_test).astype(np.float32)

def normalize_up_down(x, y):
    samples = zip(x, y)
    numpy.random.shuffle(samples)
    up = []
    down = []
    for item in samples:
        if item[1][0] > 0:
            up.append(item)
        elif item[1][0] < 0:
            down.append(item)
    min_length = min(len(up), len(down))
    out = up[:min_length] + down[:min_length]
    numpy.random.shuffle(out)
    return zip(*out)


X_train, Y_train = normalize_up_down(X_train, Y_train)
X_test, Y_test = normalize_up_down(X_test, Y_test)

X_train = np.asarray(X_train).astype(np.float32)
Y_train = np.asarray(Y_train).astype(np.float32)

X_test = np.asarray(X_test).astype(np.float32)
Y_test = np.asarray(Y_test).astype(np.float32)

    
def load_test_data():
    
    X_out = X_test
    Y_out = Y_test
 
    return DenseDesignMatrix(X=X_out, y=Y_out)
def load_train_data():
    
    X_out = X_train
    Y_out = Y_train
 
    return DenseDesignMatrix(X=X_out, y=Y_out)

# %%
print np.shape(X_train)
print np.shape(Y_train)

print np.shape(X_test)
print np.shape(Y_test)
# Out:
# (3418, 9)
# (3418, 1)
# (350, 9)
# (350, 1)

# %%
train = DenseDesignMatrix(X=X_train, y=Y_train)
valid = DenseDesignMatrix(X=X_test[::5], y=Y_test[::5])
train_monitor = DenseDesignMatrix(X=X_train[::5], y=Y_train[::5])

# %%
monitor = live_monitoring.LiveMonitoring()

# %%
if model:
    model.monitor.disable_logging()

monitor.req_sock.close()
monitor.pub_sock.close()
monitor = live_monitoring.LiveMonitoring()

h0 = mlp.Sigmoid(layer_name='h0', dim=100, sparse_init=5) #9
h1 = mlp.Sigmoid(layer_name='h1', dim=100, sparse_init=5) #18
ylayer = mlp.Linear(layer_name='y', dim=1, sparse_init=3)

layers = [h0, h1, ylayer]
model = mlp.MLP(layers, nvis=9)

monitoring = dict(valid=valid, train=train_monitor)
termination = EpochCounter(10000)
extensions = [monitor]

algorithm = sgd.SGD(.05, batch_size=100, cost=Dropout(.8),
                     monitoring_dataset = monitoring, termination_criterion = termination)

#algorithm = bgd.BGD(batch_size=2000, cost=WeightDecay({'h0':1., 'h1':1.}),
 #                   monitoring_dataset = monitoring, termination_criterion = termination)

train_job = Train(train, model, algorithm, extensions=extensions)


train_job.main_loop()
# Out:
# Parameter and initial learning rate summary:
# 	h0_W: 0.0500000007451
# 	h0_b: 0.0500000007451
# 	h1_W: 0.0500000007451
# 	h1_b: 0.0500000007451
# 	y_W: 0.0500000007451
# 	y_b: 0.0500000007451
# Compiling sgd_update...
# Compiling sgd_update done. Time elapsed: 0.629114 seconds
# Time this epoch: 0.040637 seconds
# Time this epoch: 0.040039 seconds
# Time this epoch: 0.040431 seconds
# Time this epoch: 0.039698 seconds
# Time this epoch: 0.040025 seconds
# Time this epoch: 0.039610 seconds
# Time this epoch: 0.040075 seconds
# Time this epoch: 0.039666 seconds
# Time this epoch: 0.040155 seconds
# Time this epoch: 0.039753 seconds
# Time this epoch: 0.040143 seconds
# Time this epoch: 0.039538 seconds
# Time this epoch: 0.040133 seconds
# Time this epoch: 0.039537 seconds
# Time this epoch: 0.040081 seconds
# Time this epoch: 0.039781 seconds
# Time this epoch: 0.040016 seconds
# Time this epoch: 0.039663 seconds
# Time this epoch: 0.040135 seconds
# Time this epoch: 0.039611 seconds
# Time this epoch: 0.039997 seconds
# Time this epoch: 0.039766 seconds
# Time this epoch: 0.039928 seconds
# Time this epoch: 0.039686 seconds
# Time this epoch: 0.040148 seconds
# Time this epoch: 0.039865 seconds
# Time this epoch: 0.040230 seconds
# Time this epoch: 0.039645 seconds
# Time this epoch: 0.039920 seconds
# Time this epoch: 0.039786 seconds
# Time this epoch: 0.040109 seconds
# Time this epoch: 0.039483 seconds
# Time this epoch: 0.040032 seconds
# Time this epoch: 0.040223 seconds
# Time this epoch: 0.039963 seconds
# Time this epoch: 0.039666 seconds
# Time this epoch: 0.039977 seconds
# Time this epoch: 0.040024 seconds
# Time this epoch: 0.040223 seconds
# Time this epoch: 0.040017 seconds
# Time this epoch: 0.041208 seconds
# Time this epoch: 0.040080 seconds
# Time this epoch: 0.040980 seconds
# Time this epoch: 0.040218 seconds
# Time this epoch: 0.040514 seconds
# Time this epoch: 0.040088 seconds
# Time this epoch: 0.040933 seconds
# Time this epoch: 0.040662 seconds
# Time this epoch: 0.040636 seconds
# Time this epoch: 0.039988 seconds
# Time this epoch: 0.041568 seconds
# Time this epoch: 0.040538 seconds
# Time this epoch: 0.040413 seconds
seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-134-cc1c542a5fcc> in <module>()
#      26
#      27
# ---> 28 train_job.main_loop()
#
# /home/ubuntu/temp/pylearn2/pylearn2/train.pyc in main_loop(self, time_budget)
#     205                             log, None, final_msg='Time this epoch:',
#     206                             callbacks=[self.training_seconds.set_value]):
# --> 207                         rval = self.algorithm.train(dataset=self.dataset)
#     208                     if rval is not None:
#     209                         raise ValueError("TrainingAlgorithm.train should not "
#
# /home/ubuntu/temp/pylearn2/pylearn2/training_algorithms/sgd.pyc in train(self, dataset)
#     450
#     451         on_load_batch = self.on_load_batch
# --> 452         for batch in iterator:
#     453             for callback in on_load_batch:
#     454                 callback(*batch)
#
# /home/ubuntu/temp/pylearn2/pylearn2/utils/iteration.pyc in next(self)
#     861             rval = self._next(next_index)
#     862         else:
# --> 863             rval = self._fallback_next(next_index)
#     864
#     865         if not self._return_tuple and len(rval) == 1:
#
# /home/ubuntu/temp/pylearn2/pylearn2/utils/iteration.pyc in _fallback_next(self, next_index)
#     879         return tuple(
#     880             fn(data[next_index]) if fn else data[next_index]
# --> 881             for data, fn in safe_izip(self._raw_data, self._convert)
#     882         )
#     883
#
# /home/ubuntu/temp/pylearn2/pylearn2/utils/iteration.pyc in <genexpr>((data, fn))
#     879         return tuple(
#     880             fn(data[next_index]) if fn else data[next_index]
# --> 881             for data, fn in safe_izip(self._raw_data, self._convert)
#     882         )
#     883
#
# /home/ubuntu/temp/pylearn2/pylearn2/utils/iteration.pyc in <lambda>(batch, dspace, sp)
#     829                 # of the loop.
#     830                 fn = (lambda batch, dspace=dspace, sp=sp:
# --> 831                       dspace.np_format_as(batch, sp))
#     832
#     833             self._convert[i] = fn
#
# /home/ubuntu/temp/pylearn2/pylearn2/space/__init__.pyc in np_format_as(self, batch, space)
#     484         return self._format_as(is_numeric=True,
#     485                                batch=batch,
# --> 486                                space=space)
#     487
#     488     def _check_sizes(self, space):
#
# /home/ubuntu/temp/pylearn2/pylearn2/space/__init__.pyc in _format_as(self, is_numeric, batch, space)
#     544         self._check_sizes(space)
#     545
# --> 546         return self._format_as_impl(is_numeric, batch, space)
#     547
#     548     def _format_as_impl(self, is_numeric, batch, target_space):
#
# /home/ubuntu/temp/pylearn2/pylearn2/space/__init__.pyc in _format_as_impl(self, is_numeric, batch, space)
#    1309                                       (self, space))
#    1310
# -> 1311         return _cast(result, dtype=to_type)
#    1312
#    1313     @functools.wraps(Space._undo_format_as_impl)
#
# /home/ubuntu/temp/pylearn2/pylearn2/space/__init__.pyc in _cast(arg, dtype)
#     193         return arg
#     194
# --> 195     assert dtype in tuple(t.dtype for t in theano.scalar.all_types)
#     196
#     197     if isinstance(arg, tuple):
#
# /home/ubuntu/temp/pylearn2/pylearn2/space/__init__.pyc in <genexpr>((t,))
#     193         return arg
#     194
# --> 195     assert dtype in tuple(t.dtype for t in theano.scalar.all_types)
#     196
#     197     if isinstance(arg, tuple):
#
# KeyboardInterrupt:

# %%
with open(r"zackmodel2.pickle", "wb") as output_file:
    pickle.dump(model, output_file)

# %%
import copy

X = T.matrix()
X = model.get_input_space().make_theano_batch()
Y = model.fprop(X)
f = function([X], Y)

def compare(x, y, set_name, shuffle=False):
    x = copy.deepcopy(x)
    y = copy.deepcopy(y)
    if shuffle:
        numpy.random.shuffle(y)
    test = f(x)

    comparison = zip(y, test)

    print set_name
    for i in range(1):
        right = 0
        for row in comparison:
            if float(row[0][i]) * float(row[1][i]) > 0:
                right += 1
        print right/float(len(x))
        
compare(X_train, Y_train, "training set")
compare(X_test, Y_test, "test set")
compare(X_train, Y_train,  "training set", True)
compare(X_test, Y_test, "test set", True)
# Out:
# training set
# 0.5
# test set
# 0.5
# training set
# 0.5
# test set
# 0.5

# %%
ben;s
Training set
0.518590998043
0.526139222812
0.51607492312
test set
0.0542353927873
0.0539558289069
0.0567514677104
# Out:
#   File "<ipython-input-85-5a7ccd4f90b6>", line 2
#     Training set
#                ^
# SyntaxError: invalid syntax

# %%
random
0.477774671512
0.476376852111
0.474326716988

0.519280205656
0.517994858612
0.510711225364

# %%
up = 0
down = 0

for x in range(0, 1):
    for row in Y_train:

        if float(row[x]) > 0:
            up += 1
        else:
            down += 1


    print up /(down + up)
    
up = 0
down = 0

for x in range(0, 1):
    for row in Y_test:

        if float(row[x]) > 0:
            up += 1
        else:
            down += 1


    print up /(down + up)
# Out:
# 0.5
# 0.489906377999
# 0.484493856056
# 0.5
# 0.498571428571
# 0.494285714286

# %%
def compare(x, y, set_name, shuffle=False):
    x = copy.deepcopy(x)
    y = copy.deepcopy(y)
    if shuffle:
        numpy.random.shuffle(y)
    test = f(x)

    comparison = zip(y, test)
    numpy.random.shuffle(comparison)
    print set_name
    for i in range(1):
        right = 0
        for row in comparison:
            print row[0][i] , row[1][i]
            if float(row[0][i]) * float(row[1][i]) >= 0:
                right += 1
        print right/float(len(x))
        
compare(X_test, Y_test, "training set")
# Out:
# training set
# -0.00097 0.0537463
# -0.0014 0.058129
# 0.0009 0.0537314
# 0.0027 0.0522816
# 0.0002 0.0586716
# 0.0009 0.0556624
# -0.00218 0.0567249
# 0.0003 0.0577136
# 0.0024 0.0564936
# 0.0004 0.0548297
# 0.0006 0.0526003
# -0.0028 0.05516
# -0.00019 0.0563366
# -0.0005 0.0556521
# -0.0036 0.0547888
# 0.0015 0.0566153
# -0.0006 0.0522331
# -0.0003 0.0570474
# -0.0001 0.0528378
# -0.00146 0.054871
# -0.0026 0.0533007
# -0.0018 0.0521195
# 0.0009 0.058303
# 0.0004 0.0563605
# -0.00088 0.0549184
# 0.0013 0.0581126
# 0.0005 0.0520051
# -0.0003 0.0582578
# 0.0004 0.054371
# 0.00188 0.0547634
# 0.0002 0.0538323
# 0.0004 0.0552502
# -0.00021 0.0568463
# -0.0008 0.052563
# 0.0004 0.0556907
# 0.0006 0.0502097
# -0.00013 0.0535714
# -0.0002 0.0549968
# 0.0014 0.0546542
# -0.0063 0.0521179
# -0.0013 0.0552526
# 0.0001 0.0579427
# -0.0003 0.0546643
# 0.0003 0.0550732
# -0.0005 0.0535126
# -0.00024 0.0546754
# 8e-05 0.0550743
# -0.00013 0.05446
# 0.00148 0.0595879
# -0.0004 0.0551118
# 0.0007 0.051938
# -0.0009 0.0500878
# -0.0013 0.054528
# -0.00039 0.0549073
# 0.0013 0.0562631
# 0.00013 0.0558554
# -0.0003 0.0579639
# 0.0009 0.0565346
# -0.0001 0.0549597
# 0.0001 0.0576207
# 0.00215 0.0549785
# -0.0008 0.0518178
# -0.0002 0.0562015
# 0.0021 0.0546815
# -0.0001 0.0561589
# 0.00036 0.0536207
# -0.0015 0.0553936
# -0.0018 0.0572025
# 0.0003 0.0550341
# 0.00028 0.055008
# -0.00178 0.056741
# 0.0014 0.0545165
# -0.0014 0.0543991
# 0.00025 0.05334
# 0.0004 0.0518014
# 0.0002 0.0529399
# -0.0003 0.0519493
# -0.0002 0.0548513
# 0.0004 0.0556196
# 0.0006 0.0560428
# 3e-05 0.0533878
# 0.0015 0.0578127
# 0.00045 0.0571087
# -0.0004 0.0569531
# -0.0007 0.0522377
# 0.0011 0.053098
# -0.0003 0.0572048
# 0.00125 0.0560975
# 0.0007 0.0521357
# 0.0001 0.052204
# 0.0003 0.0519431
# -0.001 0.0562534
# -0.0003 0.0530255
# 0.00053 0.0536477
# 0.00014 0.0544726
# 0.0013 0.0551754
# 0.0016 0.054786
# -0.0001 0.0529027
# 0.0003 0.0552036
# -0.0004 0.0561423
# -0.0013 0.0505492
# 0.0003 0.0538119
# -0.0002 0.0500868
# -0.001 0.0518555
# 0.00027 0.0573162
# -0.0006 0.0516605
# -0.0002 0.0534455
# 0.0019 0.0553681
# -0.0001 0.0514186
# 0.0025 0.053381
# 0.0001 0.057138
# -0.0011 0.0529477
# -0.00025 0.0549147
# 0.5

# %%
#monitoring = dict(valid=valid)
monitoring = dict()
#termination = MonitorBased(channel_name="valid_y_misclass", N=100)
termination = EpochCounter(10)
#extensions = [best_params.MonitorBasedSaveBest(channel_name="valid_y_misclass",
#save_path="train_best.pkl"), monitor]
extensions = [monitor]


algorithm = sgd.SGD(0.1, batch_size=100, cost=Dropout(),
                    monitoring_dataset = monitoring, termination_criterion = termination)

save_path = "train_bes3t.pkl"
#if os.path.exists(save_path):
#    model = serial.load(save_path)
#else:
#    print 'Running training'
#    train_job = Train(train, model, algorithm, extensions=extensions, save_path="train.pkl", save_freq=1)
#    train_job.main_loop()

train_job = Train(train, model, algorithm, extensions=extensions, save_path="train.pkl", save_freq=1)
train_job.main_loop()


#X = model.get_input_space().make_batch_theano()
#Y = model.fprop(X)

#y = T.argmax(Y, axis=1)
#f = function([X], y)
#yhat = f(test.X)

#y = np.where(test.get_targets())[1]
#print 'accuracy', (y==yhat).sum() / y.size
