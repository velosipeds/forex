# %%
import glob
import pybrain
from pybrain.structure import FeedForwardNetwork
from pybrain.structure import LinearLayer, SigmoidLayer
from pybrain.structure import FullConnection
from pybrain.datasets import SupervisedDataSet
from pybrain.supervised.trainers import BackpropTrainer
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline
import random
import ast
import time
import sqlalchemy
from sqlalchemy import *
from sqlalchemy import event
import sqlite3
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import *
from sqlalchemy.dialects.mysql import LONGTEXT
import urllib2
import urllib
import json
import glob
import pprint
import dateutil.parser
import pprint
pp = pprint.PrettyPrinter(indent=4)
from collections import defaultdict

# %%
Base = declarative_base()
mysql_url = "mysql://forex:yummy4money@forex.c2ggnaqt6wye.us-west-1.rds.amazonaws.com/forex"
sqlite_url = 'sqlite:///database.db'
db = create_engine(mysql_url, echo=False)
session = sessionmaker()
session.configure(bind=db)
session = session()

# %%
class ForexDatapoint(Base):
    __tablename__ = "forex_data"
    datapoint_id = Column(Integer, autoincrement=True, primary_key = True)
    exchange = Column(String(10))
    timestamp = Column(DateTime)
    open = Column(Numeric(14, 8))
    close = Column(Numeric(14, 8))
    high = Column(Numeric(14, 8))
    low = Column(Numeric(14, 8))

    def __init__(self, exchange, timestamp, open, close, high, low):
        self.exchange = exchange
        self.timestamp = timestamp
        self.open = open
        self.close = close
        self.high = high
        self.low = low

# %%
class Article(Base):
    __tablename__ = "articles"
    article_id = Column(Integer, autoincrement=True, primary_key = True)
    web_id = Column(String(150))
    title = Column(String(200))
    api_url = Column(String(300))
    web_url = Column(String(300))
    section_id = Column(String(80))
    body = Column(LONGTEXT)
    pub_date = Column(DateTime)
    subtitle = Column(Text)
    wordcount = Column(Integer)
       
    def __init__(self, web_id, title, api_url, web_url, 
                    section_id, body, pub_date, subtitle, wordcount):
        self.web_id = web_id
        self.title = title
        self.api_url = api_url
        self.web_url = web_url
        self.section_id = section_id
        self.body = body
        self.pub_date = pub_date
        self.subtitle = subtitle
        self.wordcount = wordcount
        
        
class Tag(Base):
    __tablename__ = "tags"
    category = Column(String(80))
    article_id = Column(Integer, primary_key = True)
    section = Column(String(200), primary_key = True)

    def __init__(self, category, article_id, section):
        self.category = category
        self.article_id = article_id
        self.section = section

# %%
raw_data = session.query(ForexDatapoint.timestamp, ForexDatapoint.open, ForexDatapoint.close).\
            filter_by(exchange="EURUSD").\
            order_by(ForexDatapoint.timestamp.desc())\
            [0:3000000]

# %%
#grouped_data = defaultdict(list)
#for i in raw_data:
#     grouped_data[i[0].date()].append({"time":i[0].time(), "open":i[1], "close":i[2]})

# %%
grouped_data = defaultdict(list)
for i in raw_data:
     grouped_data[i[0].date()].append((i[1] + i[2]) / 2)

# %%
print "there are %s days of forex data loaded" % len(grouped_data)
# Out:
# there are 2672 days of forex data loaded

# %%
moving_average = defaultdict(list)

for key, value in grouped_data.iteritems():
    if len(value) > 1000:
        interval = len(value) / 19
        moving_average[key].append(value[0])
        for i in range(1,18):
            nearby = (value[i*interval - interval/2 : i*interval + interval/2])
            average = sum(nearby) / len(nearby)
            moving_average[key].append(average)
        
        moving_average[key].append(value[len(value)-1])

# %%
moving_average_list = []
for key in sort(moving_average.keys()):
    moving_average_list.append(moving_average[key])

# %%
normalized_moving_average = []
for items in moving_average_list:
    average = sum(items)/len(items)
    normalized_moving_average.append([(x-average)*1000 for x in items])
moving_average_list = normalized_moving_average

# %%
print moving_average_list[0]
# Out:
# [Decimal('-1.26888794567062818336163000'), Decimal('-1.14388794567062818336163000'), Decimal('-0.512436332767402376910017000'), Decimal('0.689983022071307300509338000'), Decimal('0.576273344651952461799660000'), Decimal('0.924660441426146010186757000'), Decimal('0.777079796264855687606112000'), Decimal('0.882724957555178268251273000'), Decimal('0.314176570458404074702886000'), Decimal('-0.295500848896434634974533000'), Decimal('0.207724957555178268251273000'), Decimal('1.180305602716468590831918000'), Decimal('0.80611205432937181663837000'), Decimal('-0.629371816638370118845501000'), Decimal('-0.690662139219015280135824000'), Decimal('-0.993081494057724957555178000'), Decimal('-0.737436332767402376910017000'), Decimal('-0.61888794567062818336163000'), Decimal('0.53111205432937181663837000')]

# %%
direction_list = []
for item in moving_average_list:
    direction_list.append(0 if item[0] - item[len(item)-1] > 0 else 1)
print len(direction_list)
# Shift over 1
direction_list = direction_list[1:]
print len(direction_list)
# Out:
# 2001
# 2000

# %%
plot([item[0] for item in moving_average_list[1:50]])
plot([1.3 if item < 1 else 1.2 for item in direction_list[1:50]])

# %%
for key, value in enumerate(moving_average_list):
    direction =  direction_list[key]
    direction2 = value[len(value)-1] - value[0]
    print direction, direction2
# Out:
# 1 1.80000000000000000000000000
# 0 -7.800000000000000000000000000
# 1 7.500000000000000000000000000
# 0 -4.550000000000000000000000000
# 1 5.700000000000000000000000000
# 1 2.850000000000000000000000000
# 0 -8.550000000000000000000000000
# 1 11.10000000000000000000000000
# 1 1.200000000000000000000000000
# 0 -5.050000000000000000000000000
# 0 -6.600000000000000000000000000
# 1 2.650000000000000000000000000
# 1 0.600000000000000000000000000
# 1 8.150000000000000000000000000
# 1 2.600000000000000000000000000
# 0 -0.550000000000000000000000000
# 0 -1.950000000000000000000000000
# 0 -1.350000000000000000000000000
# 1 0.750000000000000000000000000
# 1 2.050000000000000000000000000
# 1 2.350000000000000000000000000
# 1 1.750000000000000000000000000
# 0 -0.70000000000000000000000000
# 1 10.10000000000000000000000000
# 0 -4.350000000000000000000000000
# 1 3.250000000000000000000000000
# 0 -0.600000000000000000000000000
# 0 -2.900000000000000000000000000
# 0 -6.250000000000000000000000000
# 1 4.150000000000000000000000000
# 0 -4.300000000000000000000000000
# 0 -7.100000000000000000000000000
# 1 5.500000000000000000000000000
# 1 5.400000000000000000000000000
# 0 -2.400000000000000000000000000
# 1 1.350000000000000000000000000
# 0 -8.20000000000000000000000000
# 1 2.350000000000000000000000000
# 1 2.850000000000000000000000000
# 1 1.250000000000000000000000000
# 1 4.750000000000000000000000000
# 1 0.750000000000000000000000000
# 0 -3.900000000000000000000000000
# 0 -3.550000000000000000000000000
# 0 -0.650000000000000000000000000
# 1 0.350000000000000000000000000
# 0 -9.400000000000000000000000000
# 1 6.900000000000000000000000000
# 0 -3.000000000000000000000000000
# 0 -6.300000000000000000000000000
# 0 -6.850000000000000000000000000
# 1 7.58000000000000000000000000
# 0 -4.670000000000000000000000000
# 0 -2.795000000000000000000000000
# 0 -0.565000000000000000000000000
# 1 16.52500000000000000000000000
# 0 -2.275000000000000000000000000
# 0 -5.205000000000000000000000000
# 0 -3.635000000000000000000000000
# 1 6.255000000000000000000000000
# 0 -0.365000000000000000000000000
# 0 -1.055000000000000000000000000
# 1 8.105000000000000000000000000
# 1 7.930000000000000000000000000
# 0 -7.105000000000000000000000000
# 1 9.340000000000000000000000000
# 0 -2.560000000000000000000000000
# 0 -8.275000000000000000000000000
# 0 -5.270000000000000000000000000
# 1 5.070000000000000000000000000
# 0 -6.440000000000000000000000000
# 0 -1.385000000000000000000000000
# 0 -3.750000000000000000000000000
# 1 14.66500000000000000000000000
# 1 6.550000000000000000000000000
# 1 5.055000000000000000000000000
# 1 0.750000000000000000000000000
# 1 5.860000000000000000000000000
# 1 3.970000000000000000000000000
# 1 5.700000000000000000000000000
# 0 -1.745000000000000000000000000
# 1 6.100000000000000000000000000
# 1 5.205000000000000000000000000
# 0 -0.940000000000000000000000000
# 1 7.225000000000000000000000000
# 1 5.300000000000000000000000000
# 1 1.730000000000000000000000000
# 0 -3.460000000000000000000000000
# 1 1.785000000000000000000000000
# 1 5.045000000000000000000000000
# 1 1.035000000000000000000000000
# 1 14.32500000000000000000000000
# 1 6.885000000000000000000000000
# 0 -2.005000000000000000000000000
# 1 1.105000000000000000000000000
# 0 -3.325000000000000000000000000
# 1 25.52000000000000000000000000
# 1 13.95000000000000000000000000
# 0 -7.180000000000000000000000000
# 0 -9.260000000000000000000000000
# 1 6.73000000000000000000000000
# 0 -5.845000000000000000000000000
# 1 4.375000000000000000000000000
# 0 -2.330000000000000000000000000
# 0 -14.12500000000000000000000000
# 1 11.77000000000000000000000000
# 0 -11.78000000000000000000000000
# 1 15.57000000000000000000000000
# 1 0.340000000000000000000000000
# 1 1.255000000000000000000000000
# 1 0.585000000000000000000000000
# 0 -11.84000000000000000000000000
# 1 3.980000000000000000000000000
# 1 5.645000000000000000000000000
# 0 -4.315000000000000000000000000
# 0 -0.985000000000000000000000000
# 1 5.045000000000000000000000000
# 0 -1.525000000000000000000000000

# %%
from pybrain.datasets            import ClassificationDataSet
from pybrain.utilities           import percentError
from pybrain.tools.shortcuts     import buildNetwork
from pybrain.supervised.trainers import BackpropTrainer
from pybrain.structure.modules   import SoftmaxLayer

# %%
from pylab import ion, ioff, figure, draw, contourf, clf, show, hold, plot
from scipy import diag, arange, meshgrid, where
from numpy.random import multivariate_normal

# %%
alldata = ClassificationDataSet(19, 1, nb_classes=2)
for key, value in enumerate(moving_average_list):
    alldata.addSample(tuple(value), direction_list[key])

# %%
#alldata = ClassificationDataSet(2, 1, nb_classes=2)
#for key, value in enumerate(moving_average_list):
#    alldata.addSample((value[0], value[len(value)-1]), direction_list[key])

# %%
tstdata, trndata = alldata.splitWithProportion( 0.15 )

# %%
trndata._convertToOneOfMany( )
tstdata._convertToOneOfMany( )

# %%
print "Number of training patterns: ", len(trndata)
print "Number of testing patterns: ", len(tstdata)
print "Input and output dimensions: ", trndata.indim, trndata.outdim
print "First sample (input, target, class):"
print trndata['input'][0], trndata['target'][0], trndata['class'][0]
print trndata['input'][100], trndata['target'][2], trndata['class'][2]
# Out:
# Number of training patterns:  1701
# Number of testing patterns:  300
# Input and output dimensions:  19 2
# First sample (input, target, class):
# [-1.26888795 -1.14388795 -0.51243633  0.68998302  0.57627334  0.92466044
#   0.7770798   0.88272496  0.31417657 -0.29550085  0.20772496  1.1803056
#   0.80611205 -0.62937182 -0.69066214 -0.99308149 -0.73743633 -0.61888795
#   0.53111205] [0 1] [ 1.]
# [-0.7100726  -0.30145191  0.05372051  0.11320327  0.34682396  0.21320327
#   0.26406534 -0.37300363 -1.11093466 -0.82041742 -1.11093466 -1.20317604
#   0.11665154 -0.6738657   0.67182396  1.02872051  1.59078947  1.4649274
#   0.4399274 ] [0 1] [ 1.]

# %%
fnn = buildNetwork( trndata.indim, 2, trndata.outdim, outclass=LinearLayer )

# %%
from pybrain.structure import FeedForwardNetwork
from pybrain.structure import LinearLayer, SigmoidLayer
n = FeedForwardNetwork()
inLayer = LinearLayer(19)
hiddenLayer = SigmoidLayer(60)
#hiddenLayer2 = SigmoidLayer(30)
outLayer = LinearLayer(2)
n.addInputModule(inLayer)
n.addModule(hiddenLayer)
#n.addModule(hiddenLayer2)
n.addOutputModule(outLayer)
from pybrain.structure import FullConnection
in_to_hidden = FullConnection(inLayer, hiddenLayer)
#hidden_to_hidden = FullConnection(hiddenLayer, hiddenLayer2)
#hidden_to_out = FullConnection(hiddenLayer2, outLayer)
hidden_to_out = FullConnection(hiddenLayer, outLayer)
n.addConnection(in_to_hidden)
n.addConnection(hidden_to_out)
#n.addConnection(hidden_to_hidden)
n.sortModules()
#fnn = n

# %%
#trainer = BackpropTrainer( fnn, dataset=trndata, momentum=0.1, verbose=True, weightdecay=0.01)
trainer = BackpropTrainer( fnn, dataset=trndata, momentum=0.1, learningrate=0.01 , verbose=True, weightdecay=0.01)

# %%
for i in range(500):
    trainer.trainEpochs (1)
    print 'Percent Error on Test dataset: ' , percentError( trainer.testOnClassData (
               dataset=tstdata )
               , tstdata['class'] )
    NetworkWriter.writeToFile(fnn, 'oliv.xml')
# Out:
# Total error: 0.0816999091998
# Percent Error on Test dataset:
# 14.3333333333
# Total error:
#  0.0385771190714
# Percent Error on Test dataset:
# 11.6666666667
# Total error:
#  0.0276515136
# Percent Error on Test dataset:
# 9.33333333333
# Total error:
#  0.022307195149
# Percent Error on Test dataset:
# 7.33333333333
# Total error:
#  0.0193224995981
# Percent Error on Test dataset:
# 6.66666666667
# Total error:
#  0.0163638333185
# Percent Error on Test dataset:
# 5.0
# Total error:
#  0.0145631797214
# Percent Error on Test dataset:
# 4.33333333333
# Total error:
#  0.0132634803135
# Percent Error on Test dataset:
# 4.0
# Total error:
#  0.0128878419113
# Percent Error on Test dataset:
# 2.33333333333
# Total error:
#  0.0124350431385
# Percent Error on Test dataset:
# 1.66666666667
# Total error:
#  0.0120673927296
# Percent Error on Test dataset:
# 1.66666666667
# Total error:
#  0.0120764147878
# Percent Error on Test dataset:
# 1.33333333333
# Total error:
#  0.0118104862776
# Percent Error on Test dataset:
# 1.66666666667
# Total error:
#  0.0115355334183
# Percent Error on Test dataset:
# 2.33333333333
# Total error:
#  0.0116751452674
# Percent Error on Test dataset:
# 1.0
# Total error:
#  0.0115298201339
# Percent Error on Test dataset:
# 0.666666666667
# Total error:
#  0.0113404583527
# Percent Error on Test dataset:
# 1.0
# Total error:
#  0.0112892856345
# Percent Error on Test dataset:
# 1.33333333333
# Total error:
#  0.0110839313225
# Percent Error on Test dataset:
# 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-204-2dc3580d8c36> in <module>()
#       1 for i in range(500):
# ----> 2     trainer.trainEpochs (1)
#       3     print 'Percent Error on Test dataset: ' , percentError( trainer.testOnClassData (
#       4                dataset=tstdata )
#       5                , tstdata['class'] )
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/pybrain/supervised/trainers/trainer.pyc in trainEpochs(self, epochs, *args, **kwargs)
#      35         Additional arguments are passed on to the train method."""
#      36         for dummy in range(epochs):
# ---> 37             self.train(*args, **kwargs)
#      38
#      39     def train(self):
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/pybrain/supervised/trainers/backprop.pyc in train(self)
#      57         shuffle(shuffledSequences)
#      58         for seq in shuffledSequences:
# ---> 59             e, p = self._calcDerivs(seq)
#      60             errors += e
#      61             ponderation += p
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/pybrain/supervised/trainers/backprop.pyc in _calcDerivs(self, seq)
#      79         """Calculate error function and backpropagate output errors to yield
#      80         the gradient."""
# ---> 81         self.module.reset()
#      82         for sample in seq:
#      83             self.module.activate(sample[0])
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/pybrain/structure/networks/network.pyc in reset(self)
#     148         Module.reset(self)
#     149         for m in self.modules:
# --> 150             m.reset()
#     151
#     152     def _setParameters(self, p, owner=None):
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/pybrain/structure/modules/module.pyc in reset(self)
#      85         for buffername, l  in self.bufferlist:
#      86             buf = getattr(self, buffername)
# ---> 87             buf[:] = zeros(l)
#      88
#      89     def activateOnDataset(self, dataset):
#
# KeyboardInterrupt:

# %%
for i in range(500):
    trainer.trainEpochs( 1 )
    trnresult = percentError( trainer.testOnClassData(),
                              trndata['class'] )
    tstresult = percentError( trainer.testOnClassData(
           dataset=tstdata ), tstdata['class'] )
    if i % 10 == 0:
        print "epoch: %4d" % trainer.totalepochs, \
              "  train error: %5.2f%%" % trnresult, \
              "  test error: %5.2f%%" % tstresult

# %%
from pybrain.datasets            import ClassificationDataSet
from pybrain.utilities           import percentError
from pybrain.tools.shortcuts     import buildNetwork
from pybrain.supervised.trainers import BackpropTrainer
from pybrain.structure.modules   import SoftmaxLayer
from pybrain.tools.xml.networkwriter import NetworkWriter
from pybrain.tools.xml.networkreader import NetworkReader

# %%
import os
if  os.path.isfile('oliv.xml'): 
 fnn = NetworkReader.readFrom('oliv.xml') 
else:
 fnn = buildNetwork( trndata.indim, 64 , trndata.outdim, outclass=SoftmaxLayer )
trainer = BackpropTrainer( fnn, dataset=trndata, momentum=0.1, learningrate=0.01 , verbose=True, weightdecay=0.01)
